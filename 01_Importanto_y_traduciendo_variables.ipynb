# %% [markdown]
# <a href="https://colab.research.google.com/github/Fsalasgit/aluraCurso-Data-Visualization-Explorando_Seaborn/blob/main/01_Importanto_y_traduciendo_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Curso de
# # **Data Visualization: Explorando con Seaborn**
#
# El fin del curso es intentantar definir grupos o perfiles que tengan una probabilidad de morosidad más alta

# %% [markdown]
# # 01 - Importanto y traduciendo variables

# %% [markdown]
# **Importando base de datos**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
datos = pd.read_csv('/content/drive/MyDrive/alura_archivos/bases/DataVisualizacion_ExplorandoConSeaborn/credit_card.csv')
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# **Traduciendo variables**

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columnas = {
    'LIMIT_BAL' : 'limite',
    'CHECKING_ACCOUNT' : 'cuenta_corriente',
    'EDUCATION' : 'escolaridad',
    'MARRIAGE' : 'estado_civil',
    'AGE' : 'edad',
    'BILL_AMT' : 'valor_factura',
    'PAY_AMT' : 'valor_pago',
    'DEFAULT' : 'moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columnas)
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# cambio de nombre de las variables de los valores

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes' : 'si', 'No': 'no'
}

# %%
#Usamos map para cambiar los datos de las variables
#pero al no atribuir a la base de datos solamente genera los nuevos valores.
tarjetas.cuenta_corriente.map(
    dic_cuenta
)
# Out:
# 0       si
# 1       si
# 2       si
# 3       si
# 4       no
#         ..
# 1495    si
# 1496    no
# 1497    no
# 1498    no
# 1499    no
# Name: cuenta_corriente, Length: 1500, dtype: object

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(
    dic_cuenta
)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               si       2.University      Married    24
# 1   36132               si       2.University       Single    26
# 2   27099               si       2.University       Single    34
# 3   15055               si       2.University      Married    37
# 4  150550               no  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University' : '2.Universidad',
    '3.Graduate School' : '3.Post-grado',
    '1.High School' : '1.Colegio'
}

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(
    dic_escolaridad
)
tarjetas.head()
# Out:
#    limite cuenta_corriente    escolaridad estado_civil  edad  valor_factura  \
# 0    6022               si  2.Universidad      Married    24       934.0122
# 1   36132               si  2.Universidad       Single    26       519.3975
# 2   27099               si  2.Universidad       Single    34      4223.5297
# 3   15055               si  2.Universidad      Married    37     14522.9563
# 4  150550               no   3.Post-grado       Single    29    124060.1253
#
#    valor_pago  moroso
# 0      0.0000       1
# 1      0.0000       1
# 2    457.0698       0
# 3    602.2000       0
# 4  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(
    {
       'Married': 'casado', 'Single' : 'soltero'
    }
)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente    escolaridad estado_civil  edad  valor_factura  \
# 0    6022               si  2.Universidad       casado    24       934.0122
# 1   36132               si  2.Universidad      soltero    26       519.3975
# 2   27099               si  2.Universidad      soltero    34      4223.5297
# 3   15055               si  2.Universidad       casado    37     14522.9563
# 4  150550               no   3.Post-grado      soltero    29    124060.1253
#
#    valor_pago  moroso
# 0      0.0000       1
# 1      0.0000       1
# 2    457.0698       0
# 3    602.2000       0
# 4  16560.5000       0

# %% [markdown]
# # 02 - Análisis exploratorio de variables

# %%
# !pip install seaborn

# %% [markdown]
# importando Seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: lida, missingno

# %%
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente    escolaridad estado_civil  edad  valor_factura  \
# 0    6022               si  2.Universidad       casado    24       934.0122
# 1   36132               si  2.Universidad      soltero    26       519.3975
# 2   27099               si  2.Universidad      soltero    34      4223.5297
# 3   15055               si  2.Universidad       casado    37     14522.9563
# 4  150550               no   3.Post-grado      soltero    29    124060.1253
#
#    valor_pago  moroso
# 0      0.0000       1
# 1      0.0000       1
# 2    457.0698       0
# 3    602.2000       0
# 4  16560.5000       0

# %%
sns.distplot(tarjetas['limite'])
# Out:
# <ipython-input-26-c84ce6169819>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tarjetas['limite'])
# <Axes: xlabel='limite', ylabel='Density'>

# %%
sns.displot(
    data = tarjetas,
    x = 'limite'
);

# %%
sns.displot(
    data = tarjetas,
    x = 'limite',
    hue = 'escolaridad' #Mostramos un mejor detalle de las columnas
);

# %% [markdown]
# Analisis II

# %%
#Crear un columna del porcentaje usado del límite disponible
#iu = indice de uso
tarjetas['iu'] = tarjetas['valor_factura']/ tarjetas['limite']

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente    escolaridad estado_civil  edad  valor_factura  \
# 0    6022               si  2.Universidad       casado    24       934.0122
# 1   36132               si  2.Universidad      soltero    26       519.3975
# 2   27099               si  2.Universidad      soltero    34      4223.5297
# 3   15055               si  2.Universidad       casado    37     14522.9563
# 4  150550               no   3.Post-grado      soltero    29    124060.1253
#
#    valor_pago  moroso        iu
# 0      0.0000       1  0.155100
# 1      0.0000       1  0.014375
# 2    457.0698       0  0.155856
# 3    602.2000       0  0.964660
# 4  16560.5000       0  0.824046

# %%
sns.displot(
    data = tarjetas,
    x = 'iu'
);

# %% [markdown]
# Hay un público significativo que usa poco del límite que tienen disponible

# %% [markdown]
# **Estilos y colores**

# %%
sns.set_style('whitegrid')

# %%
sns.displot(
    data= tarjetas,
    x='limite',
    hue= 'escolaridad'
)

# %%
sns.set_style('darkgrid')

# %%
sns.displot(
    data= tarjetas,
    x='limite',
    hue= 'escolaridad',
    palette = 'inferno' #Cambiamos el tema de los colores
)

# %%
sns.displot(
    data= tarjetas,
    x='limite',
    hue= 'escolaridad',
    palette = 'inferno_r' #Cambiamos el tema de los colores y con _r invertimos la paleta
)

# %% [markdown]
# # 03 - Comparando y analizando variables categóricas

# %% [markdown]
# Análisis de variables categóricas

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente    escolaridad estado_civil  edad  valor_factura  \
# 0    6022               si  2.Universidad       casado    24       934.0122
# 1   36132               si  2.Universidad      soltero    26       519.3975
# 2   27099               si  2.Universidad      soltero    34      4223.5297
# 3   15055               si  2.Universidad       casado    37     14522.9563
# 4  150550               no   3.Post-grado      soltero    29    124060.1253
#
#    valor_pago  moroso        iu
# 0      0.0000       1  0.155100
# 1      0.0000       1  0.014375
# 2    457.0698       0  0.155856
# 3    602.2000       0  0.964660
# 4  16560.5000       0  0.824046

# %%
sns.countplot(
    data = tarjetas,
    x='cuenta_corriente'
)
# Out:
# <Axes: xlabel='cuenta_corriente', ylabel='count'>

# %%
sns.countplot(
    data = tarjetas,
    x='cuenta_corriente',
    hue='moroso',
    palette = 'coolwarm'
)
# Out:
# <Axes: xlabel='cuenta_corriente', ylabel='count'>

# %%
sns.catplot(
    data = tarjetas,
    x = 'estado_civil',
    y = 'limite'
)

# %%
sns.catplot(
    data = tarjetas,
    x = 'estado_civil',
    y = 'limite',
    hue = 'moroso'
)

# %%
sns.catplot(
    data = tarjetas,
    x = 'estado_civil',
    y = 'limite',
    hue = 'moroso',
    dodge= 'True' #Separa las columnas para una mejor visualización
)

# %%
sns.swarmplot(
    data = tarjetas,
    x = 'escolaridad',
    y = 'iu'
)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='escolaridad', ylabel='iu'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 27.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(
    data= tarjetas,
    x= 'escolaridad',
    y = 'iu'
)
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %%
sns.boxplot(
    data= tarjetas,
    x= 'escolaridad',
    y = 'iu',
    hue='moroso',
    palette='bone'
)
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %%
sns.violinplot(
    data=tarjetas,
    x='escolaridad',
    y = 'iu'
)
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %%
sns.violinplot(
    data=tarjetas,
    x='escolaridad',
    y = 'iu',
    hue = 'moroso'
)
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %%
tarjetas.edad.unique()
#Al tener tantos datos, no es factible utilizar los graficos visto anteriormente
#Como solucion se unirá por rango de edad
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
tarjetas.edad.unique().max()
# Out:
# 75

# %%
tarjetas.edad.unique().min()
# Out:
# 21

# %%
bins=[20,30,40,50,80]
nombres = ['20-30' ,'30-40' ,'40-50' ,'50+']

tarjetas['rango_edad'] = pd.cut(
    tarjetas.edad,
    bins,
    labels = nombres
    )

tarjetas.head()
# Out:
#    limite cuenta_corriente    escolaridad estado_civil  edad  valor_factura  \
# 0    6022               si  2.Universidad       casado    24       934.0122
# 1   36132               si  2.Universidad      soltero    26       519.3975
# 2   27099               si  2.Universidad      soltero    34      4223.5297
# 3   15055               si  2.Universidad       casado    37     14522.9563
# 4  150550               no   3.Post-grado      soltero    29    124060.1253
#
#    valor_pago  moroso        iu rango_edad
# 0      0.0000       1  0.155100      20-30
# 1      0.0000       1  0.014375      20-30
# 2    457.0698       0  0.155856      30-40
# 3    602.2000       0  0.964660      30-40
# 4  16560.5000       0  0.824046      20-30

# %%
sns.boxplot(
    data = tarjetas,
    x= 'rango_edad',
    y= 'limite'
)
# Out:
# <Axes: xlabel='rango_edad', ylabel='limite'>

# %% [markdown]
# # 04-Análisis de variables numéricas y regresión

# %% [markdown]
# Analisis de variables numéricas

# %%
sns.displot(
    data = tarjetas,
    x = 'limite',
    hue = 'escolaridad'
);

# %%
sns.displot(
    data = tarjetas,
    x = 'limite',
    col = 'escolaridad', #cambiamos hue por col para terner un grafico por cada una de las variables
);

# %%
sns.displot(
    data = tarjetas,
    x = 'limite',
    col = 'escolaridad',
    kind ='kde' #Funcion de densidad
);

# %%
sns.displot(
    data = tarjetas,
    x = 'limite',
    col = 'escolaridad',
    kind ='kde',
    hue = 'moroso'
);

# %%
sns.displot(
    data = tarjetas,
    x = 'limite',
    col = 'escolaridad',
    kind ='kde',
    hue = 'rango_edad'
);

# %% [markdown]
# Dispersión

# %%
sns.scatterplot(
    data= tarjetas,
    x = 'iu',
    y = 'valor_factura'
);

# %%
sns.scatterplot(
    data= tarjetas,
    x = 'iu',
    y = 'valor_factura',
    hue = 'cuenta_corriente'
);

# %%
sns.lmplot(
    data= tarjetas,
    x= 'iu',
    y = 'valor_factura'
);

# %% [markdown]
# Test de hipótesis

# %%
sns.lmplot(
    data= tarjetas,
    x= 'iu',
    y = 'valor_factura',
    col = 'moroso'
);

# %%
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<sup>
# La distribucion de los grupos morosos y no morosos es la misma

# %% [markdown]
# H<sup>alt<sup>
# La distribucion de los grupos moroso y no moroso no es la misma

# %%
moroso = tarjetas.query("moroso == 1").valor_factura
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: valor_factura, Length: 117, dtype: float64

# %%
no_moroso = tarjetas.query("moroso == 0").valor_factura
no_moroso
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: valor_factura, Length: 1383, dtype: float64

# %%
resultado = ranksums(moroso, no_moroso)

# %%
print('El p_value de nuestro test es {} %'.format(((resultado.pvalue)*100).round(2)))
# Out:
# El p_value de nuestro test es 1.04 %

# %% [markdown]
# # 05 - Análisis conjunta de variables

# %% [markdown]
# **Joinplot**

# %%
sns.jointplot(
    data = tarjetas,
    x = 'edad',
    y = 'limite'
);

# %%
sns.jointplot(
    data = tarjetas,
    x = 'edad',
    y = 'limite',
    kind = 'kde'
);

# %%
sns.jointplot(
    data = tarjetas,
    x = 'edad',
    y = 'limite',
    kind = 'hex'
);

# %%
sns.jointplot(
    data = tarjetas,
    x = 'edad',
    y = 'limite',
    kind = 'kde',
    hue = 'moroso'
);

# %% [markdown]
# **Pairplot**

# %%
tarjetas.describe()
# Out:
#               limite         edad  valor_factura    valor_pago       moroso  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#                 iu
# count  1500.000000
# mean      0.388237
# std       0.341923
# min       0.000188
# 25%       0.049209
# 50%       0.308976
# 75%       0.704090
# max       0.998010

# %%
sns.pairplot(
    data = tarjetas,
)

# %%
sns.pairplot(
    data = tarjetas,
    hue = 'escolaridad',
    palette = 'Accent'
)
